# %%
from VGG19_cheater import ClassCheater
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Simple example: tiger to jaguar

# %%
# tiger = 292, jaguar = 290
cheater = ClassCheater('images/tiger.jpg', 290)
# Out:
# WARNING:tensorflow:From /home/regzand/.local/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
cheater.get_image()
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9666F87588>

# %%
cheater.get_predictions()
# Out:
# [[('n02129604', 'tiger', 0.8180914),
#   ('n02123159', 'tiger_cat', 0.18129694),
#   ('n02128925', 'jaguar', 0.00018565617),
#   ('n02123045', 'tabby', 0.00018444554),
#   ('n02127052', 'lynx', 7.563496e-05)]]

# %%
cheater.optimize()

# %%
cheater.get_image()
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F96657774E0>

# %%
cheater.get_predictions()
# Out:
# [[('n02128925', 'jaguar', 0.98903173),
#   ('n02128385', 'leopard', 0.004942506),
#   ('n02129604', 'tiger', 0.0034688027),
#   ('n02123159', 'tiger_cat', 0.0017475986),
#   ('n02130308', 'cheetah', 0.00019479469)]]

# %%
cheater.get_image().save('outputs/tiger-jaguar.jpg')

# %% [markdown]
# ## Harder example: tiger to burrito

# %%
# tiger = 292, burrito = 965
cheater = ClassCheater('images/tiger.jpg', 965)

# %%
cheater.get_image()
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F9665495940>

# %%
cheater.get_predictions()
# Out:
# [[('n02129604', 'tiger', 0.8180914),
#   ('n02123159', 'tiger_cat', 0.18129694),
#   ('n02128925', 'jaguar', 0.00018565617),
#   ('n02123045', 'tabby', 0.00018444554),
#   ('n02127052', 'lynx', 7.563496e-05)]]

# %%
cheater.optimize()

# %%
cheater.get_image()
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F96651FCA20>

# %%
cheater.get_predictions()
# Out:
# [[('n07880968', 'burrito', 0.9842355),
#   ('n01943899', 'conch', 0.0030530463),
#   ('n12144580', 'corn', 0.0018341553),
#   ('n07583066', 'guacamole', 0.001393197),
#   ('n03958227', 'plastic_bag', 0.00057045155)]]

# %%
cheater.get_image().save('outputs/tiger-burrito.jpg')
